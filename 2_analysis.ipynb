# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df_base= pd.read_csv("datasets/dataset_clean.csv", sep=";")
df_partners=pd.read_csv("datasets/dataset_partners.csv", sep=";")
df_date = pd.read_csv("datasets/dataset_couple.csv", sep=";")

# %%
df_partners['Age'] = df_partners['Age'].fillna(df_partners['Age'].median())

# %%
df_partners['Age']=df_partners['Age'].astype('int64')

# %%
fig = px.box(df_partners, x="Gender", y="Age", title='Age of participants', color='Gender', width=500)
fig.show()

# %%
fig = px.pie(df_partners, names="Goal for the evening", title='Goal of the evening', width=700)
fig.show()

# %%
fig = px.histogram(df_date, x='Match', color='Match', width=500, text_auto=True, title='Nombre de matches')
fig.show()

# %%
fig = px.histogram(df_partners, x='Satisfaction of people met', title='Satisfaction of people met', text_auto=True, width=600)
fig.show()

# %%
df_base["Match"]=df_base["Match"].apply(lambda x : 1 if x=="Yes" else 0)
df_date["Match"]=df_date["Match"].apply(lambda x : 1 if x=="Yes" else 0)
df_date['Decision partner1_P2']=df_date["Decision partner1_P2"].apply(lambda x : 1 if x=="Yes" else 0)
df_date['Decision partner1_P1']=df_date["Decision partner1_P1"].apply(lambda x : 1 if x=="Yes" else 0)

# %%
df_male_partners = df_partners[df_partners['Gender']=="Male"]
df_female_partners = df_partners[df_partners['Gender']=="Female"]

male_results=[]
female_results=[]

cols = ['Looking for attractive (before evening)',
        'Looking for sincere (before evening)',
        'Looking for intelligent (before evening)',
        'Looking for fun (before evening)',
        'Looking for ambitious (before evening)',
        'Looking for shared interests (before evening)']

for c in cols:
    row = [c,df_male_partners[c].mean()]
    male_results.append(row)

for c in cols:
    row = [c,df_female_partners[c].mean()]
    female_results.append(row)


df_what_are_males_looking_for = pd.DataFrame(male_results, columns=['Attribute', 'Average'])

df_what_are_females_looking_for = pd.DataFrame(female_results, columns=['Attribute', 'Average'])

# %%
df_what_are_males_looking_for.sort_values('Average')
# Out:
#                                        Attribute    Average
# 4         Looking for ambitious (before evening)   8.823956
# 5  Looking for shared interests (before evening)  10.982271
# 1           Looking for sincere (before evening)  16.379600
# 3               Looking for fun (before evening)  17.600839
# 2       Looking for intelligent (before evening)  19.387418
# 0        Looking for attractive (before evening)  27.248800

# %%
df_what_are_females_looking_for.sort_values('Average')
# Out:
#                                        Attribute    Average
# 5  Looking for shared interests (before evening)  12.697836
# 4         Looking for ambitious (before evening)  12.818476
# 3               Looking for fun (before evening)  17.299108
# 0        Looking for attractive (before evening)  18.020372
# 1           Looking for sincere (before evening)  18.222230
# 2       Looking for intelligent (before evening)  20.971004

# %%
fig = px.histogram(df_partners, x='How many called you', text_auto=True, title="How many called after the event ?")
fig.show()

# %%
fig=px.histogram(df_base,width=800,x='Rating of attractive (date)',barnorm = 'percent',color='Decision partner1',text_auto=True, nbins=10, title='Swipe right vs. rating of attractiveness of the date')
fig.show()

# %%
fig=px.histogram(df_base,width=800,barnorm = 'percent',x='Importance of attractiveness in decision (after event)',color='Decision partner1',text_auto=True, nbins=9, title='Importance of attractiveness in decision (after the event)')
fig.show()

# %%
fig=px.histogram(df_date,x='Rating of fun (date)_P2',color='Decision partner1_P1', barnorm='percent', nbins=20)
fig.show()

# %%
fig=px.histogram(df_date,x='Rating of attractive (date)_P1',color='Decision partner1_P1', nbins=30)
fig.show()

# %%
fig = px.histogram(df_partners,x='Expected number of interested people', text_auto=True,color='Gender', title='Expected number of interested people by gender')
fig.show()

# %%
fig = px.histogram(df_base[df_base['Match']==1], x='Number of the date', title='Matches according to the number of the date of the partner')
fig.show()

# %%
from plotly.subplots import make_subplots

fig = go.Figure()
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]],subplot_titles=['First date', 'Last date','First date', 'Last date'])
fig.add_trace(go.Pie(labels=df_base[(df_base['Number of the date']==1)]['Partner2 Decision']),
              1, 1)
fig.add_trace(go.Pie(labels=df_base[(df_base['Number of the date']==20)]['Partner2 Decision']),
              1, 2)

fig.update_layout(
    width=800,
    title_text="Chances of getting a 'Yes' from the date in the first and last date",
    # Add annotations in the center of the donut pies.
    legend=dict(
        title=dict(
            text="Partner likes you"
        ))
    )
fig.show()

# %%
data_corr = df_base.corr(numeric_only=True)

# %%
data_corr["Match"].sort_values(ascending=False)
# Out:
# Match                                                              1.000000
# Do you like the P2 (date)                                          0.305853
# How do you like P2                                                 0.305723
# Rating of fun (date)                                               0.277700
# Rating of fun of P2                                                0.277545
# Rating of shared interests (date)                                  0.270840
# Rating of shared interests of P2                                   0.270679
# Rating of attractive (date)                                        0.260837
# Rating of attractiveness of P2                                     0.260676
# Probability of P2 saying yes (date)                                0.255574
# Prob of P2 saying yes                                              0.255531
# How many called you                                                0.202762
# Rating of intelligence of P2                                       0.169532
# Rating of intelligence (date)                                      0.169448
# Rating of sincere (date)                                           0.164523
# Rating of sincere of P2                                            0.164449
# How many dates?                                                    0.156042
# Expected number of interested people                               0.143755
# Rating of ambitious of P2                                          0.140042
# Rating of ambition (date)                                          0.139927
# Estimated matches                                                  0.130592
# With how many matches                                              0.114468
# How many have you called                                           0.083922
# Importance of fun in decision (after event)                        0.073412
# How fun do you think you are (after event)                         0.060186
# Satisfaction of people met                                         0.059370
# Looking for fun (after event)                                      0.058183
# Opposite sex importance for intelligent (follow up)                0.057655
# Interest in clubbing                                               0.055435
# How fun do you think you are (before evening)                      0.051066
# Opposite sex importance for intelligent (after event)              0.050187
# Looking for fun (follow up)                                        0.048441
# Other peers importance for fun (after event)                       0.044244
# How important is fun (mid evening)                                 0.041916
# Looking for fun (before evening)                                   0.041652
# Preference of fun (date)                                           0.041483
# Interest in yoga                                                   0.036601
# How attractive do you think you are (before evening)               0.036439
# How fun do you think you are perceived (after event)               0.035596
# How important is attractiveness (mid evening)                      0.034685
# Self rating of fun (mid evening)                                   0.034441
# Interest in dining                                                 0.033912
# Self rating of sincerity (mid evening)                             0.032972
# How fun do you think you are (follow up)                           0.032086
# Interest in art                                                    0.031545
# Importance of fun in decision (follow up)                          0.031287
# How fun do you think you are perceived (before evening)            0.031251
# Correlation of interests                                           0.031121
# How important is intelligence (mid evening)                        0.030289
# Self rating of attractiveness (mid evening)                        0.028229
# How happy do you expect to be                                      0.027880
# Interest in concerts                                               0.027034
# Other peers importance for attractive (follow up)                  0.026911
# Opposite sex importance for intelligent (before evening)           0.026303
# Other peers importance for intelligent (follow up)                 0.025856
# Interest in hiking/camping                                         0.024143
# Importance of intelligence in decision (after event)               0.023666
# How ambitious do you think you are (follow up)                     0.023452
# How attractive do you think you are perceived (follow up)          0.023098
# Interest in music                                                  0.023093
# Opposite sex importance for ambitious (after event)                0.022647
# Opposite sex importance for ambitious (follow up)                  0.022489
# Other peers importance for attractive (before evening)             0.022201
# Interest in playing sports                                         0.021666
# Other peers importance for attractive (after event)                0.021107
# Interest in reading                                                0.020222
# How fun do you think you are perceived (follow up)                 0.019793
# How attractive do you think you are (after event)                  0.019545
# Self rating of ambition (mid evening)                              0.018389
# Looking for ambitious (follow up)                                  0.017858
# Looking for intelligent (after event)                              0.017572
# Opposite sex importance for fun (after event)                      0.017118
# How ambitious do you think you are perceived (before evening)      0.016646
# Opposite sex importance for attractive (before evening)            0.016455
# Preference of attractive (date)                                    0.015663
# Importance of intelligence in decision (follow up)                 0.015619
# Self rating of intelligence (mid evening)                          0.015541
# Interest in museums                                                0.014954
# Looking for attractive (before evening)                            0.014950
# Looking for intelligent (before evening)                           0.014087
# Preference of intelligence (date)                                  0.013761
# Interest in gaming                                                 0.013543
# Looking for attractive (follow up)                                 0.013198
# How intelligent do you think you are (follow up)                   0.012516
# Opposite sex importance for attractive (follow up)                 0.012187
# How ambitious do you think you are (before evening)                0.010592
# How attractive do you think you are (follow up)                    0.010484
# How ambitious do you think you are perceived (after event)         0.010241
# Interest in bodybuilding and exercices                             0.009470
# Importance of shared interests in decision (follow up)             0.009375
# How sincere do you think you are perceived (after event)           0.009049
# Opposite sex importance for fun (follow up)                        0.008972
# How ambitious do you think you are perceived (follow up)           0.008534
# Other peers importance for fun (before evening)                    0.007408
# How sincere do you think you are perceived (before evening)        0.006101
# Other peers importance for intelligent (before evening)            0.006084
# How intelligent do you think you are (before evening)              0.004327
# How intelligent do you think you are (after event)                 0.004210
# How attractive do you think you are perceived (after event)        0.003578
# How attractive do you think you are perceived (before evening)     0.002790
# Other peers importance for fun (follow up)                         0.002770
# How ambitious do you think you are (after event)                   0.002361
# Importance of attractiveness in decision (follow up)               0.002066
# How intelligent do you think you are perceived (before evening)    0.001084
# Interest in theater                                                0.000087
# Opposite sex importance for ambitious (before evening)            -0.000028
# idg                                                               -0.000544
# Partner ID                                                        -0.000770
# Partner2 ID                                                       -0.001041
# Interest in shopping                                              -0.001333
# How sincere do you think you are (before evening)                 -0.001965
# Other peers importance for shared interests (follow up)           -0.002477
# How important is sincerity (mid evening)                          -0.004173
# Looking for ambitious (before evening)                            -0.004444
# Interest in watching sports                                       -0.004472
# Preference of ambition (date)                                     -0.004650
# How sincere do you think you are (follow up)                      -0.005582
# How intelligent do you think you are perceived (after event)      -0.006038
# Station number where started                                      -0.006530
# How sincere do you think you are (after event)                    -0.007775
# Looking for attractive (after event)                              -0.007931
# Looking for intelligent (follow up)                               -0.009373
# Opposite sex importance for fun (before evening)                  -0.009985
# Station number when met                                           -0.010210
# Importance of ambition in decision (after event)                  -0.012546
# Importance of attractiveness in decision (after event)            -0.012614
# Opposite sex importance for attractive (after event)              -0.012737
# Other peers importance for shared interests (before evening)      -0.012975
# How intelligent do you think you are perceived (follow up)        -0.013012
# Partner2 Race                                                     -0.013088
# Other peers importance for ambitious (before evening)             -0.013695
# Opposite sex importance for sincere (before evening)              -0.014294
# Interest in tv                                                    -0.014542
# Partner IID                                                       -0.015806
# Partner2 IID                                                      -0.016343
# Looking for ambitious (after event)                               -0.017033
# Wave                                                              -0.017404
# Importance of sincerity in decision (after event)                 -0.017819
# Opposite sex importance for sincere (after event)                 -0.019685
# Looking for shared interests (after event)                        -0.020172
# Looking for sincere (after event)                                 -0.021800
# Interest in movies                                                -0.022989
# Other peers importance for ambitious (follow up)                  -0.022991
# Other peers importance for intelligent (after event)              -0.025827
# Importance of religion                                            -0.026014
# Importance of sincerity in decision (follow up)                   -0.028560
# Other peers importance for shared interests (after event)         -0.029636
# How important is ambition (mid evening)                           -0.030083
# How sincere do you think you are perceived (follow up)            -0.031990
# Looking for sincere (before evening)                              -0.032325
# Preference of sincere (date)                                      -0.032391
# How important is shared interests (mid evening)                   -0.033093
# Other peers importance for ambitious (after event)                -0.033253
# Number of people in wave                                          -0.033257
# Opposite sex importance for shared interests (after event)        -0.034974
# Age                                                               -0.035055
# Looking for shared interests (follow up)                          -0.035289
# Partner2 Age                                                      -0.035865
# Other peers importance for sincere (follow up)                    -0.037210
# Opposite sex importance for shared interests (before evening)     -0.037709
# Opposite sex importance for sincere (follow up)                   -0.038329
# Number of the date                                                -0.038731
# Importance of ambition in decision (follow up)                    -0.039387
# Looking for sincere (follow up)                                   -0.043789
# Looking for shared interests (before evening)                     -0.048318
# Preference of shared interests (date)                             -0.048399
# Importance of race                                                -0.049032
# Other peers importance for sincere (after event)                  -0.053498
# Other peers importance for sincere (before evening)               -0.058424
# Importance of shared interests in decision (after event)          -0.060104
# Opposite sex importance for shared interests (follow up)          -0.077851
# Met P2 before (date)                                              -0.106569
# Name: Match, dtype: float64
